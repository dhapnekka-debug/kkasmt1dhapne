# %% [markdown]
# <a href="https://colab.research.google.com/github/dhapnekka-debug/kkasmt1dhapne/blob/main/Fungsi_print_dhapne_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print  ( "Halo dunia!" )
print  ( 'Selamat datang di Python' )
# Out:
# Halo dunia!
# Selamat datang di Python

# %% [markdown]
# #Aturan & contoh pemakaian

# %%
print ( "Belajar Python itu menyenangkan!" )
# Out:
# Belajar Python itu menyenangkan!

# %%
nama = "dhapne"
print (nama)
# Out:
# dhapne

# %% [markdown]
# #Menampilkan teks + variabel

# %%
umur = 16
print (f"umur saya {umur} tahun")
# Out:
# umur saya 16 tahun

# %%
nama = "dhapne"
print ("halo " + nama)
# Out:
# halo dhapne

# %%
umur = 16
print ("umur saya", umur, "tahun")
# Out:
# umur saya 16 tahun

# %%
umur = 16
print ("umur saya " + str(umur) + " tahun")
# Out:
# umur saya 16 tahun

# %%
harga_telur = 26000
print("harga telur per 1 kg adalah", harga_telur)
# Out:
# harga telur per 1 kg adalah 26000

# %%
harga_telur = 26000
print("harga telur per 1 kg adalah " + str(harga_telur))
# Out:
# harga telur per 1 kg adalah 26000

# %%
nama_pembeli = "dhapne"
print("nama pembeli telur adalah " + nama_pembeli)
# Out:
# nama pembeli telur adalah dhapne

# %% [markdown]
# Latihan soal
# 1. Tampilkan teks bebas: hari ini saya bahagia belajar bahasa python
# 2. Tampilkan nilai variable: mata_pelajaran_favorit = kode dan kecerdasan buatan
# 3. Tampilkan nilai variable: nilai_kka = 100
# 4. Tampilkan teks bebas dan nilai variable dengan tiga metode (f string, "+", "'") : " nilai KKA saya adalah {nilai_kka} loh! "

# %% [markdown]
# #Escape Character

# %%
print ("nama: dhapne ursa rahman")
print ("kelas: XI.1")
print ("nomor absen: 07")
# Out:
# nama: dhapne ursa rahman
# kelas: XI.1
# nomor absen: 07

# %%
print ("nama\t\t: dhapne ursa rahman\nkelas\t\t: XI.1\nnomor absen\t: 07")
# Out:
# nama		: dhapne ursa rahman
# kelas		: XI.1
# nomor absen	: 07

# %%
print(  """nama:dhapne ursa rahman
kelas:XI.1
nomor absen:07"""  )
# Out:
# nama: dhapne ursa rahman
# kelas: XI.1
# nomor absen: 07

# %% [markdown]
# #jawaban latihan soal

# %%
print ( "hari ini saya bahagia belajar bahasa python" )
# Out:
# hari ini saya bahagia belajar bahasa phyton

# %%
mata_pelajaran_favorit = " kode dan kecerdasan buatan "
print ("mata pelajaran favorit saya adalah" + mata_pelajaran_favorit )
# Out:
# mata pelajaran favorit saya adalah kode dan kecerdasan buatan

# %%
nilai_kka =  100
print ( "nilai kka adalah "  +  str  (nilai_kka) )
# Out:
# nilai kka adalah 100

# %%
nilai_kka =   100
print (  "nilai KKA saya adalah "   +   str   (nilai_kka) +   " loh!"  )
# Out:
# nilai KKA saya adalah 100 loh!

# %%
nilai_kka =  100
print ( f"nilai KKA saya adalah {nilai_kka} loh!"   )
# Out:
# nilai KKA saya adalah 100 loh!

# %%
print (   """nilai KKA saya 100 loh! """  )
# Out:
# nilai KKA saya 100 loh!

# %%
print ('ja\'far shodiq')
# Out:
# ja'far shodiq

# %%
print ("ja'far shodiq")
# Out:
# ja'far shodiq

# %%
print ("bu shinta berkata, \"semua harus menyimak pelajaran. \"")
# Out:
# bu shinta berkata, "semua harus menyimak pelajaran. "

# %%
print ( 'bu shinta berkata, "semua harus menyimak pelajara n. "' )
# Out:
# bu shinta berkata, "semua harus menyimak pelajaran. "

# %%
print( "lokasi file video karnaval ada di D:\\karnaval 20 25\\mp4" )
# Out:
# lokasi file vidio karnaval ada di D:\karnaval 2025\mp4

# %% [markdown]
# #parameter fungsi print

# %%
Tahun = 2009
Bulan = "Juli"
Tanggal = 7

print(Tanggal, end=" ")
print(Bulan, end=" ")
print(Tahun)
# Out:
# 7 Juli 2009

# %%
Tahun = 2009
Bulan = "Juli"
Tanggal = 7

print(Tanggal, Bulan, Tahun, sep="/")
# Out:
# 7/Juli/2009

# %% [markdown]
# #Latihan
# Tanggal-Bulan-Tahun

# %%
Nama_depan = "dhapne"
Nama_belakang = "ursa"

print(Nama_depan, Nama_belakang)
# Out:
# dhapne ursa

# %%
Nama_depan = "dhapne"
Nama_belakang = "ursa"

print(Nama_depan, end=" ")
print(Nama_belakang)
# Out:
# dhapne ursa

# %%
print ("bu shinta berkata, \"berikut adalah judul pelajaran hari senin selasa rabu silakan disimpan di laptop masing-masing di folder local disk D:\\jadwal pelajaran\\kelas XI semester 1.\"")
print ("\njadwal pelajaran mingguan")
print ("=============================")
print ("jam\tsenin\t\tselasa\t\trabu")
print ("jam 1\tmatematika\tbahasa\t\tinformatika")
print ("jam 2\tbahasa ingr.\tsejarah\t\tma'rifatullah")
print ("jam 3\tinformatika\tolahraga\tbiologi")
# Out:
# bu shinta berkata, "berikut adalah judul pelajaran hari senin selasa rabu silakan disimpan di laptop masing-masing di folder local disk D:\jadwal pelajaran\kelas XI semester 1."
#
# jadwal pelajaran mingguan
# =============================
# jam	senin		selasa		rabu
# jam 1	matematika	bahasa		informatika
# jam 2	bahasa ingr.	sejarah		ma'rifatullah
# jam 3	informatika	olahraga	biologi
