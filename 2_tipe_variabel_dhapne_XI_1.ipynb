# %% [markdown]
# <a href="https://colab.research.google.com/github/dhapnekka-debug/kkasmt1dhapne/blob/main/2_tipe_variabel_dhapne_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Konsep Dasar

# %%
email_user_1 =   "dhapnekka@gmail.com"
print (email_user_1)
# Out:
# dhapnekka@gmail.com

# %%
sabun_lifebuoy = 15000
print(sabun_lifebuoy)
# Out:
# 15000

# %%
print(sabun_lifebuoy*5)
# Out:
# 75000

# %% [markdown]
# #Peraturan penulisan variabel

# %%
# Penulisan variabel hanya boleh mengggunakan huruf, angka dan underscore
# Tidak boleh menggunakan spasi
nama siswa = "Dhapne"

print (nama siswa)
# Out:
#   File "/tmp/ipython-input-1793939128.py", line 3
#     nama siswa = "Dhapne"
#          ^
# SyntaxError: invalid syntax

# %%
# Tidak boleh diawali dengan angka

1_nama_siswi = "Dhapne"
print(1_nama_siswi)
# Out:
#   File "/tmp/ipython-input-321456213.py", line 3
#     1_nama_siswi = "Dhapne"
#      ^
# SyntaxError: invalid decimal literal

# %%
# Penulisan variabel itu case sensitive/sensitif capslock
nama_siswi_1= "Dhapne"

print(Nama_siswi_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3217412115.py in <cell line: 0>()
#       2 nama_siswi_1= "Dhapne"
#       3
# ----> 4 print(Nama_siswi_1)
#
# NameError: name 'Nama_siswi_1' is not defined

# %%
# Dilarang menggunakan kata kunci di bahasa python
prin = "Dhapne"

print(prin)
# Out:
# Dhapne

# %%
# Tidak boleh pakai kata kunci python, if, for, class, print, dll
# Kalau error akibat membuat nama variabel dengan kata kunci print, maka, harus disconnect dulu
# print "Dhapne"

# print(print)

# %%
end = "Dhapne"

print(end)
# Out:
# Dhapne

# %%
# Tidak Deskriptif
_ = "Dhapne" # Bisa, tapi tidak jelas/tidak deskriptif

print(_)

# seharusnya, yang deskriptif

nama_pelanggan = "Ursa"
print(nama_pelanggan)
# Out:
# Dhapne
# Ursa

# %% [markdown]
# # Single Assignment

# %%
nama_siswa_2 = "Dhapne"
nama_siswa_3 = "Ilma"
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Dhapne
# Ilma

# %% [markdown]
# # Multiple Assignment

# %%
nama_siswa_4, nama_siswa_5 = "Sada", "Selo"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# Sada
# Selo

# %% [markdown]
# # Assign ke banyak variabel sekaligus

# %%
nilai_afa = nilai_favian = 100

print(nilai_afa)
print(nilai_favian)
# Out:
# 100
# 100

# %% [markdown]
# #Perubahan nilai variabel

# %%
nilai_afa =  95
cetakan (nilai_afa)
# Out:
# 95

# %% [markdown]
# #Aritmatika

# %%
print("5000*3")
# Out:
# 5000*3

# %%
#Operand tanpa disimpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
#Simpan operand ke dalam variabel
harga_kojek =  6000
banyak_porsi =  3

print (harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
#Simpan hasil operasi ke dalam variabel
harga_total_kojek = 3000 * 3

print (harga_total_kojek)
# Out:
# 9000

# %%
#Simpan nilai operand dan hasil operasi ke dalam v ariabel
harga_cilok =  10000
jumlah_porsi_cilok =  5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print (harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima =  100000
uang_kembalian = uang_yang_diterima - harga_total_ cilok

print (uang_kembalian)
# Out:
# 50000

# %% [markdown]
# #Soal

# %%
print(24*3)
# Out:
# 72

# %%
#Simpan hasil operasi ke dalam variabel
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %%
#Simpan operand ke dalam variabel
banyak_botol_per_kardus = 24
jumlah_kardus = 3

print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
#Simpan nilai operan dan hasil operasi ke dalam v ariabel
banyak_botol_per_kardus =  24
jumlah_kardus =  3
total_jumlah_botol = banyak_botol_per_kardus*jumla h_kardus

print (total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Tipe Variabel

# %%
usia = 65

type(usia)
# Out:
# int

# %%
berat_telur = 2.5

type(berat_telur)
# Out:
# float

# %%
nama = "dhapne"

type (nama)
# Out:
# str

# %%
remidi = False

type (remidi)
# Out:
# bool

# %%
remidi = True

type (remidi)
# Out:
# bool

# %%
koordinat_bintang = -1.5
type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8
type(koordinat_titik)
# Out:
# int

# %% [markdown]
# #Input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10                      '

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
#tipe data masih string dan harur di convert ke integer/float
luas = panjang*lebar
print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1308584410.py in <cell line: 0>()
# ----> 1 luas = panjang*lebar
#       2 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type (panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("Masukkan panjang persegi: "))
# Out:
# Masukkan panjang persegi: 10

# %%
panjang_2 = int(input("Masukkan panjang persegi: "))
lebar_2 = int(input("Masukkan lebar persegi: "))

luas_2 = panjang_2*lebar_2

print(f"Luas persegi panjang adalah {luas_2} cm^2")
# Out:
# Masukkan panjang persegi: 4
# Masukkan lebar persegi: 10
# Luas persegi panjang adalah 40 cm^2

# %% [markdown]
# #Operator Perbanding

# %%
print (8<5)
# Out:
# False

# %%
print (8>5)
# Out:
# True

# %%
print (9>=9)
# Out:
# True

# %%
print (8==5)
# Out:
# False

# %%
print (1 !=1)
# Out:
# False

# %%
a=10
b=20
c=30

print(a>c)
# Out:
# False

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka=75
kkm_kka=80

print(nilai_kka > kkm_kka)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print (8>7 and 5>6)
# Out:
# False

# %%
print (8>7 and 5<6)
# Out:
# True

# %%
print (8>7 or 5>6)
# Out:
# True

# %%
print (not(8>7 or 5>6))
# Out:
# False

# %%
print (not(8>=9 or 9!=8))
# Out:
# False

# %%
iq_min = 125
tinggi_min = 165

print (125 >=iq_min and 170 >= tinggi_min)
# Out:
# True

# %%
iq_afa = 125
tinggi_afa = 170

print (iq_afa >= iq_min and tinggi_afa >= tinggi_min)
# Out:
# True

# %%
tinggi_minimal = 165
berat_badan_minimal = 50
umur_max = 25

tinggi_farel = 170
berat_badan_farel = 55
umur_farel = 23

print(tinggi_farel >= tinggi_minimal and berat_badan_farel >= berat_badan_minimal and umur_farel <= umur_max)
# Out:
# True
