# %% [markdown]
# <a href="https://colab.research.google.com/github/dhapnekka-debug/kkasmt1dhapne/blob/main/3_Simple_app_ball_volume_XI_1_Dhapne_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Dhapne Ursa Rahman
#
# Kelas: XI.1
#
# No absen: 07
#
# Nama kelompok: Lana Del Ray

# %% [markdown]
# #Aplikasi Sederhana menghitung volume kerucut

# %%
Jari_jari = float(input("masukkan jari jari kerucut:"))
Tinggi = float(input(" masukkan tinggi kerucut:"))
pi = 3.14
volume =(1/3)* pi * (Jari_jari**2)* Tinggi
print(f" volume kerucut adalah {volume} cm^3")
# Out:
# masukkan jari jari kerucut:7
#  masukkan tinggi kerucut:14
#  volume kerucut adalah 718.0133333333333 cm^3
